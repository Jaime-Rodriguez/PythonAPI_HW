# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
import urllib, json
from datetime import datetime
import os


# Import API key
from api_keys import api_key
g_key = "AIzaSyD-6Umpef2gL592vVX2F23kkOca-hsbtyY"


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
city_df = pd.DataFrame(cities,columns=['Cities'])

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
lon = []
lat = []
hum = []
maxtemp = []
clouds = []
wind = []
new_city = []
dt = []
for index, row in city_df.iterrows():



    try:    
        # get restaurant type from df
        city = row['Cities']
        settings = {"units": "metric", "appid": api_key}
        json_df = owm.get_current(city, **settings)
        
        # Append corresponding values to their respective lists
        new_city.append(row['Cities'])
        lon.append(json_df['coord']['lon'])
        lat.append(json_df['coord']['lat'])
        hum.append(json_df['main']['humidity'])
        maxtemp.append(json_df['main']['temp_max'])
        clouds.append(json_df['clouds']['all'])
        wind.append(json_df['wind']['speed'])
        dt.append(json_df['dt'])
        print(json_df['coord']['lon'])
        print(city)
        time.sleep(.5)     

    # For any errors (specifically the 404 Error) move on to the next record    
    except:
        next
    print("-----------")
# Out:
# 53.87
# sharkan
# -----------
# -----------
# -161.76
# bethel
# -----------
# 172.79
# butaritari
# -----------
# 53.91
# izhma
# -----------
# -82.12
# chiriqui grande
# -----------
# -63.58
# halifax
# -----------
# 138.6
# jamestown
# -----------
# -----------
# -58.16
# georgetown
# -----------
# -134.97
# rikitea
# -----------
# -70.91
# punta arenas
# -----------
# -94.76
# kodiak
# -----------
# 18.42
# cape town
# -----------
# 147.9
# chokurdakh
# -----------
# 10.79
# mantua
# -----------
# 147.33
# hobart
# -----------
# -60.23
# barrow
# -----------
# 125.41
# airai
# -----------
# -46
# ponta do sol
# -----------
# 166.1
# tilichiki
# -----------
# 24.1
# manta
# -----------
# 59.53
# sur
# -----------
# -2.56
# ambon
# -----------
# -159.32
# kapaa
# -----------
# -155.08
# hilo
# -----------
# -53.46
# chuy
# -----------
# -----------
# -73.75
# albany
# -----------
# -169.92
# alofi
# -----------
# -----------
# -67.52
# mar del plata
# -----------
# -----------
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dataframe with all the attributes

city_dict = {'City':new_city,'Cloudiness':clouds,'Date':dt,'Humidity':hum,'Lat':lat,'Lon':lon,'Max Temp':maxtemp,'Wind Speed':wind}
city_df = pd.DataFrame(city_dict)
city_df
# Out:
#                    City  Cloudiness        Date  Humidity    Lat     Lon  \
# 0               sharkan           0  1562208293        81  57.30   53.87
# 1                bethel          90  1562208151        93  60.79 -161.76
# 2            butaritari          17  1562208295        67   3.07  172.79
# 3                 izhma         100  1562208296        84  65.01   53.91
# 4       chiriqui grande         100  1562208297        53   8.95  -82.12
# 5               halifax          20  1562208297        82  44.65  -63.58
# 6             jamestown           0  1562208293        58 -33.21  138.60
# 7            georgetown          75  1562208299       100   6.80  -58.16
# 8               rikitea          79  1562208292        75 -23.12 -134.97
# 9          punta arenas          40  1562208300        92 -53.16  -70.91
# 10               kodiak           1  1562208302        44  39.95  -94.76
# 11            cape town          40  1562208041        93 -33.93   18.42
# ...

# %% [markdown]
# ###### Output the data to a csv

# %%
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Check to see if the output folder has been created. If not, use mkdir to create the folder
outname = 'cities.csv'
outdir = './output'
if not os.path.exists(outdir):
    os.mkdir(outdir)

fullname = os.path.join(outdir, outname)    

city_df.to_csv(fullname)

# %%
# Get country code
country=[]

for index, row in city_df.iterrows():
    Try:

        # get restaurant type from df
        lat = row['Lat']
        lon = row['Lon']
        url = f"http://api.geonames.org/countryCodeJSON?lat={lat}&lng={lon}&username=demo"
        response= urllib.request.urlopen(url)
        data = json.loads(response.read())
        country.append('countryCode')
#         print(len(data['results'][0]['address_components'][4]['short_name']))
        print(type(data))
#         country.append(data['results'][0]['address_components'][4]['short_name'])
#         print(data)
#         print(data)['results'][0]['address_components'])
        # Append corresponding values to their respective lists
#         print(json_df['coord']['lon'])
#         print(city)
     Except:
        'N/A'

# %%
print(data['results'][0]['address_components'][4]['short_name'])
# Out:
# TAS

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ###### Define the font weights I'll be using in my plots

# %%
font = {'weight' : 'bold',
        'size'   : 22}
font2 = {'weight' : 'bold',
        'size'   : 12}
font3 = {'weight' : 'normal',
        'size'   : 9}

# %% [markdown]
# ###### Define today's run date for our plots

# %%
todayDate = '('+datetime.today().strftime('%m-%d-%Y')+')'

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat, maxtemp,linewidths=1, edgecolors='black',alpha=.9)
plt.title('Latitude vs. Temperature Plot '+todayDate,**font2)
plt.xlabel('Latitude',**font3)
plt.ylabel('Max Temperature (F)',**font3)
plt.grid()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat, hum,linewidths=1, edgecolors='black',alpha=.9)
plt.title('Latitude vs. Humidity Plot '+todayDate,**font2)
plt.xlabel('Latitude',**font3)
plt.ylabel('Humidity (%)',**font3)
plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, clouds,linewidths=1, edgecolors='black',alpha=.9)
plt.title('Latitude vs. Cloudiness Plot '+todayDate,**font2)
plt.xlabel('Latitude',**font3)
plt.ylabel('Cloudiness (%)',**font3)
plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, wind,linewidths=1, edgecolors='black',alpha=.9)
plt.title('Latitude vs. Wind Speed '+todayDate,**font2)
plt.xlabel('Latitude',**font3)
plt.ylabel('Wind Speed (MPH)',**font3)
plt.grid()

# %%
fig, ax = plt.subplots(2,2, figsize = (15,10))

fig.suptitle('Latitude and Weather '+todayDate,**font)

ax[0,0].scatter(lat, maxtemp,linewidths=1, edgecolors='black',alpha=.9)
ax[0,0].set_title('Latitude vs. Temperature Plot',**font2)
ax[0,0].set_xlabel('Latitude',**font3)
ax[0,0].set_ylabel('Max Temperature (F)',**font3)
ax[0,0].grid()

ax[1,0].scatter(lat, hum,linewidths=1, edgecolors='black',alpha=.9)
ax[1,0].set_title('Latitude vs. Humidity Plot',**font2)
ax[1,0].set_xlabel('Latitude',**font3)
ax[1,0].set_ylabel('Humidity (%)',**font3)
ax[1,0].grid()

ax[0,1].scatter(lat, clouds,linewidths=1, edgecolors='black',alpha=.9)
ax[0,1].set_title('Latitude vs. Cloudiness Plot',**font2)
ax[0,1].set_xlabel('Latitude',**font3)
ax[0,1].set_ylabel('Cloudiness (%)',**font3)
ax[0,1].grid()

ax[1,1].scatter(lat, wind,linewidths=1, edgecolors='black',alpha=.9)
ax[1,1].set_title('Latitude vs. Wind Speed',**font2)
ax[1,1].set_xlabel('Latitude',**font3)
ax[1,1].set_ylabel('Wind Speed (MPH)',**font3)
ax[1,1].grid()

fig.tight_layout(rect=[0,0.03,1,0.95])
